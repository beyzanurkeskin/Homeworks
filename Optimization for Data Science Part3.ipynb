# %% [markdown]
# Beyza Nur Keskin
#
# 150200320

# %% [markdown]
# ### Question 2 (a)

# %%
import numpy as np
import matplotlib.pyplot as plt


def f(x):                                            # define the function
    return x * (x-3) * (x-2) * x


x = np.linspace(-2, 4, 100)                          # define the interval
fig = plt.figure(figsize=(8, 5))
plt.plot(x, f(x), color='purple', linestyle='--')
plt.title('Function Plot')
plt.grid(True)

plt.show()

# %% [markdown]
# ### Question 2 (b)

# %%
from mpl_toolkits.mplot3d import Axes3D



def f(x):                                      # efine the function
    return x * (x-3) * (x-2) * x


x = np.linspace(-2, 4, 100)                    # define the interval

# Plot the function
fig = plt.figure(figsize=(8, 10))
ax1 = fig.add_subplot(211)
ax1.plot(x, f(x), color='purple')
ax1.grid(True)



ax2 = fig.add_subplot(212, projection='3d')    # define the 3D plot


def quadratic_fit_search(): 
    pass


def secant_method():
    pass

plt.show()

# %% [markdown]
# ### Question 3 (I used my contour plot in my previous homework)

# %%
def f(x, y):
                                                                      # definig the function to plot
    
    return  (-x **2) + (2 *( y**2)) + (x*y) + (3 * x) + (4 * y)


x = np.linspace(-3, 3, 100)                                           # definig the interval to plot the surface
y = np.linspace(-3, 3, 100)
X, Y = np.meshgrid(x, y)


D = f(X, Y)                                                           # calculating the function values for each point in the grid


levels = np.linspace(20, 40, 21)                                      # defini the levels for the contour plot


plt.contour(X, Y, D, levels=levels)                                   # creatng the contour plot

U, V = np.gradient(D)                                                 # calculating the gradient of the function to
U = U / np.sqrt(U**2 + V**2)                                          #  plot arrows representing the direction of the gradient
V = V / np.sqrt(U**2 + V**2)


plt.quiver(X, Y, U, V)                                                # plotng the arrows representing the gradient


fig = plt.figure(figsize=(10, 8))                                     # ploting the function as a 3D surface
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X1, X2, Z, cmap='coolwarm')
plt.show()


plt.show()

# %% [markdown]
# ### Question 4 (I used my contour plot in my previous homework)

# %%
def f(x1, x2):
                                                                      # definig the function to plot
    b0, b1, b2, b3 = 0, 3, 2, 0
    return (x1 - b0) * (x2 - b1) * (x1 - b2) * (x2 - b3)


x = np.linspace(-3, 3, 100)                                           # definig the interval to plot the surface
y = np.linspace(-3, 3, 100)
X, Y = np.meshgrid(x, y)


D = f(X, Y)                                                           # calculating the function values for each point in the grid


levels = np.linspace(20, 40, 21)                                      # defini the levels for the contour plot


plt.contour(X, Y, D, levels=levels)                                   # creatng the contour plot

U, V = np.gradient(D)                                                 # calculating the gradient of the function to
U = U / np.sqrt(U**2 + V**2)                                          #  plot arrows representing the direction of the gradient
V = V / np.sqrt(U**2 + V**2)


plt.quiver(X, Y, U, V)                                                # plotng the arrows representing the gradient


fig = plt.figure(figsize=(10, 8))                                     # ploting the function as a 3D surface
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X1, X2, Z, cmap='coolwarm')
plt.show()


plt.show()
