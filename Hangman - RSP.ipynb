# %%
import random
sen = 0
comp = 0
while True:
    a = ["taş","kağıt","makas"]
    print("taş: 1", "kağıt: 2","makas:3")
    b = input("hamlen: ")
    c = random.choice(a)
    print(c)
    
    
    if c == "taş":
        if b == "1": 
            print("berabere")
            
        elif b == "3":
            print("kazandın")
            sen += 1
            
        elif b == "2": 
            print("kaybettin")
            comp += 1
            
    if c == "kağıt":
        if b == "2": 
            print("berabere")
            
        elif b == "1":
            print("kazandın")
            sen += 1
            
        elif b == "3":  
            print("kaybettin")
            comp += 1
            
    if c == "makas":
        if b == "3": 
            print("berabere")
            
        elif b == "2":
            print("kazandın")
            sen += 1
            
        elif b == "1":  
            print("kaybettin")
            comp += 1
            
    if b == "q":
        break
print("-----skor-----")
print("sen: "+ str(sen) , "pc: "+ str(comp))
# Out:
# taş: 1 kağıt: 2 makas:3
# hamlen: 1
# taş
# berabere
# taş: 1 kağıt: 2 makas:3
# hamlen: 1
# kağıt
# kazandın
# taş: 1 kağıt: 2 makas:3
# hamlen: 2
# makas
# kazandın
# taş: 1 kağıt: 2 makas:3
# hamlen: 2
# makas
# kazandın
# taş: 1 kağıt: 2 makas:3
# hamlen: 1
# makas
# kaybettin
# taş: 1 kağıt: 2 makas:3
# hamlen: 3
# makas
# berabere
# taş: 1 kağıt: 2 makas:3
# hamlen: 2
# taş
# kaybettin
# taş: 1 kağıt: 2 makas:3
# hamlen: 1
# taş
# berabere
# taş: 1 kağıt: 2 makas:3
# hamlen:
# taş
# taş: 1 kağıt: 2 makas:3
# hamlen: 1
# makas
# kaybettin
# taş: 1 kağıt: 2 makas:3
# hamlen: 2
# makas
# kazandın
# taş: 1 kağıt: 2 makas:3
# hamlen: 2
# makas
# kazandın
# taş: 1 kağıt: 2 makas:3
# hamlen: q
# kağıt
# -----skor-----
# sen: 5 pc: 3

# %%
import random


def pick_random_word():
    word_list = ["python", "c", "java", "swift", "html", "css", "go", "ruby"]
    random_word = random.choice(word_list)
    return random_word


def make_word_classified(word):
    classified_list = ["_" for i in word]
    return classified_list


def guess():
    word = pick_random_word()
    
    
    classified_word = make_word_classified(word)
    print(*classified_word)
    total_attempts = 0

    while True:
        try:
            answer = input("Guess a letter (Write only one letter)>: ").lower()
            if len(answer) > 1:
                raise Exception
        except Exception:
            print("Only one letter at a time!")
            continue
        total_attempts += 1

        if total_attempts >= 7:
            print("Sorry but you lost!")
            try_again = input("Wanna play again? (write y or n) >: ")
            if try_again == 'y':
                guess()
            elif try_again == 'n':
                print("Goodbye!")
                quit()

        for i in range(len(word)):
                if answer == word[i]:
                    classified_word[i] = answer
                if "".join(classified_word) == word:
                    print("You won!")
                    quit()

        print(*classified_word, f"\nTotal attempts left: {7 - total_attempts}")


guess()
# Out:
# _ _
# Guess a letter (Write only one letter)>: f
# _ _
# Total attempts left: 6
# Guess a letter (Write only one letter)>: a
# _ _
# Total attempts left: 5
# Guess a letter (Write only one letter)>:
# _ _
# Total attempts left: 4
# Guess a letter (Write only one letter)>: o
# _ o
# Total attempts left: 3
